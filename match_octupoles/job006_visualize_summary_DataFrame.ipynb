# %%
import pandas as pd
import pickle

# %%
tt = pickle.load(open('summary_QpxQpy1_b3b5b7_270GeV_ayyScan_axyNoConstraint_LOD.pkl', 'rb'))

# %%
tt
# Out:
#        ayy [1/m]     axy [1/m]  klof [1/m^4]  klod [1/m^4]  O3_lof [T/m^3]  \
# 0  -3.386528e-10   -454.713692           0.0      0.047905             0.0
# 1  -2.000000e+03    543.957381           0.0     -1.834088             0.0
# 2  -4.000000e+03   1542.628453           0.0     -3.716080             0.0
# 3  -6.000000e+03   2541.299525           0.0     -5.598073             0.0
# 4  -8.000000e+03   3539.970598           0.0     -7.480065             0.0
# 5  -1.000000e+04   4538.641670           0.0     -9.362058             0.0
# 6  -1.200000e+04   5537.312742           0.0    -11.244050             0.0
# 7  -1.400000e+04   6535.983815           0.0    -13.126042             0.0
# 8  -1.600000e+04   7534.654887           0.0    -15.008035             0.0
# 9  -1.800000e+04   8533.325959           0.0    -16.890027             0.0
# 10 -2.000000e+04   9531.997032           0.0    -18.772020             0.0
# ...

# %%
tt['ayy [1/m]']
# Out:
# 0    -3.386528e-10
# 1    -2.000000e+03
# 2    -4.000000e+03
# 3    -6.000000e+03
# 4    -8.000000e+03
# 5    -1.000000e+04
# 6    -1.200000e+04
# 7    -1.400000e+04
# 8    -1.600000e+04
# 9    -1.800000e+04
# 10   -2.000000e+04
# 11   -3.386528e-10
# 12    2.000000e+03
# 13    4.000000e+03
# 14    6.000000e+03
# 15    8.000000e+03
# 16    1.000000e+04
# 17    1.200000e+04
# 18    1.400000e+04
# 19    1.600000e+04
# 20    1.800000e+04
# 21    2.000000e+04
# Name: ayy [1/m], dtype: float64

# %%
tt['ayy [1/m]'][0]
# Out:
# [-3.3865281417414116e-10,
#  -1999.999999999903,
#  -3999.999999999329,
#  -5999.999999999446,
#  -8000.00000000063,
#  -9999.999999999789,
#  -11999.999999999898,
#  -13999.999999999509,
#  -15999.999999999556,
#  -17999.999999999975,
#  -19999.999999999232,
#  -3.3865281417414116e-10,
#  1999.9999999998645,
#  3999.9999999993233,
#  6000.000000000394,
#  7999.9999999998745,
#  9999.999999999407,
#  11999.999999999467,
#  14000.000000000076,
#  16000.000000000671,
#  18000.00000000023,
#  19999.999999999196]
